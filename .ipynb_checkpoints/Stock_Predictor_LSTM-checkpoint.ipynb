# %%
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# %%
ticker = 'AAPL'
df = yf.download(ticker, start='2020-01-01', end='2024-12-31')
data = df[['Close']]
data = data.dropna()

scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data)

sequence_length = 60
X, y = [], []

for i in range(sequence_length, len(scaled_data)):
    X.append(scaled_data[i-sequence_length:i])
    y.append(scaled_data[i])

X, y = np.array(X), np.array(y)
# Out:
# /var/folders/qb/0lz4w3ks58v77dn8zw50wfsw0000gn/T/ipykernel_33371/3306679378.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start='2020-01-01', end='2024-12-31')
# [*********************100%***********************]  1 of 1 completed

# %%
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))

model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# /Users/dodlaprasannakumarreddy/StockLSTMProject/venv/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.fit(X, y, epochs=5, batch_size=32)
# Out:
# Epoch 1/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0952
# Epoch 2/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0060
# Epoch 3/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0037
# Epoch 4/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0037
# Epoch 5/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0029

# %%
from keras.models import load_model
model = load_model("lstm_model.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(1, 8), predicted_7_days, marker='o', label='Predicted')
plt.title(f"{ticker} - LSTM 7-Day Prediction")
plt.xlabel("Day")
plt.ylabel("Price")
plt.grid(True)
plt.legend()
plt.show()

# %%
output_df = pd.DataFrame(predicted_7_days, columns=["Predicted Price"])
output_df.index = pd.date_range(start=df.index[-1] + pd.Timedelta(days=1), periods=7)
display(output_df)
# Out:
#             Predicted Price
# 2025-06-25      3451.880615
# 2025-06-26      3466.154541
# 2025-06-27      3467.781250
# 2025-06-28      3439.029297
# 2025-06-29      3450.106689
# 2025-06-30      3463.964355
# 2025-07-01      3455.365723

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model.save("lstm_model.h5")
#
# NameError: name 'model' is not defined
